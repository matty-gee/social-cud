# %%
from utils import *
from utils_fmri import *

# %%
behavior = load_behavior(18001)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4.8))
ax = axs[0]
plot_rdm(behavior[['affil_coord', 'power_coord']], metric='euclidean', ax=ax, title='Cumulative sum euclidean')

ax = axs[1]
plot_rdm(behavior[['affil_runmean', 'power_runmean']], metric='euclidean', ax=ax, title='Running mean euclidean');
