# %% [markdown]
# # TODO
# double check online daa...

# %%
from utils import *

# %%
# def hull_volume(coords):
#     return ConvexHull(coords).volume
# def hull_end_volume(coords):
#     coords_by_char = organize_by_character(coords)
#     coords_by_char = np.array([char[-1] for char in coords_by_char])
#     return ConvexHull(coords_by_char).volume

# features = {"volume": lambda df: hull_volume(df[['decision_num', 'affil_coord', 'power_coord']].to_numpy()),
#             "end_volume": lambda df: hull_end_volume(df[['decision_num', 'affil_coord', 'power_coord']].to_numpy())}
# vol_df = add_summary_behavior(incl_subs, features)
# vol_df = vol_df.merge(data, on='sub_id', how='left')
# print_df(run_regression('volume ~ sni_network_size_score + dx + sex + ctq_score + age_years', data=vol_df, scale_x=True, scale_y=True))

# # online sample
# vol_df_online = add_summary_behavior(incl_subs_online, features)
# vol_df_online = vol_df_online.merge(data_online, on='sub_id', how='left')
# print_df(run_regression('volume ~ sni_num_ppl + sex + age_years', data=vol_df_online, scale_x=True, scale_y=True))

# %%
fig, ax = plt.subplots(1, 1, figsize=(4, 3))
regplot_samples(data=data, data_online=data_online, x='volume', y='sni_size_score', covariates=covariates, tail='less', ax=ax);
